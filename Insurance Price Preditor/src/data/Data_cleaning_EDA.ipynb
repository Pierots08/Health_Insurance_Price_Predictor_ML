# %%
# Importing Libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("raw/insurance.csv")

# %%
df.head()
# Out:
#          age     sex        bmi smoker     region  children       charges
# 0  21.000000    male  25.745000     no  northeast         2   3279.868550
# 1  36.976978  female  25.744165    yes  southeast         3  21454.494239
# 2  18.000000    male  30.030000     no  southeast         1   1720.353700
# 3  37.000000    male  30.676891     no  northeast         3   6801.437542
# 4  58.000000    male  32.010000     no  southeast         1  11946.625900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3630 entries, 0 to 3629
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       3630 non-null   float64
#  1   sex       3630 non-null   object
#  2   bmi       3630 non-null   float64
#  3   smoker    3630 non-null   object
#  4   region    3630 non-null   object
#  5   children  3630 non-null   int64
#  6   charges   3630 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 198.6+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  3630.000000  3630.000000  3630.000000   3630.000000
# mean     38.887036    30.629652     2.503581  12784.808644
# std      12.151029     5.441307     1.712568  10746.166743
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      29.000000    26.694526     1.000000   5654.818262
# 50%      39.170922    30.200000     3.000000   9443.807222
# 75%      48.343281    34.100000     4.000000  14680.407505
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.shape
# Out:
# (3630, 7)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# smoker      0
# region      0
# children    0
# charges     0
# dtype: int64

# %%
df.describe(include=['O'])
# Out:
#          sex smoker     region
# count   3630   3630       3630
# unique     2      2          4
# top     male     no  southeast
# freq    2029   3070       1021

# %%
# Histrogram of Medical Insurance Charges:
plt.figure(figsize=(8,5))
sns.histplot(df['charges'], kde=True)
plt.title('Medical Insurance Charges', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(df['charges'])
plt.title('Medical Insurance Charges (Boxplot)', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['age'], kde=True)
plt.title('Age', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(df['age'])
plt.title('Age (boxplot)', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['bmi'], kde=True)
plt.title('Body Mass Index', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(df['bmi'])
plt.title('Body Mass Index (Boxplot)', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['children'], kde=True)
plt.title('childrens', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(df['children'])
plt.title('childrens (Boxplot)', fontsize=20)
plt.show()

# %%
# Value Counts:
print("Male   :", df['sex'].value_counts()[0])
print("Female :", df['sex'].value_counts()[1])

# Visualization:
plt.figure(figsize=(6,4))
sns.countplot(df['sex'])
plt.title('Sex', fontsize=20)
plt.show()
# Out:
# Male   : 2029
# Female : 1601

# %%
# Value Counts:
print("Smokers     :", df['smoker'].value_counts()[1])
print("Non-Smokers :", df['smoker'].value_counts()[0])

# Visualization:
sns.countplot(df['smoker'])
sns.countplot(df['smoker'])
plt.title('Smokers', fontsize=20)
plt.show()
# Out:
# Smokers     : 560
# Non-Smokers : 3070

# %%
# Value Counts:
print("South-East region :", df['region'].value_counts()[0])
print("North-West region :", df['region'].value_counts()[1])
print("South-West region :", df['region'].value_counts()[2])
print("North-East region :", df['region'].value_counts()[3])

# Visualization:
sns.countplot(df['region'])
sns.countplot(df['region'])
plt.title('Regions', fontsize=20)
plt.show()
# Out:
# South-East region : 1021
# North-West region : 911
# South-West region : 850
# North-East region : 848

# %%
df.head()
# Out:
#          age     sex        bmi smoker     region  children       charges
# 0  21.000000    male  25.745000     no  northeast         2   3279.868550
# 1  36.976978  female  25.744165    yes  southeast         3  21454.494239
# 2  18.000000    male  30.030000     no  southeast         1   1720.353700
# 3  37.000000    male  30.676891     no  northeast         3   6801.437542
# 4  58.000000    male  32.010000     no  southeast         1  11946.625900

# %%
# Rounding up & down Age:
df['age'] = round(df['age'])

# %%
df.head()
# Out:
#     age     sex        bmi smoker     region  children       charges
# 0  21.0    male  25.745000     no  northeast         2   3279.868550
# 1  37.0  female  25.744165    yes  southeast         3  21454.494239
# 2  18.0    male  30.030000     no  southeast         1   1720.353700
# 3  37.0    male  30.676891     no  northeast         3   6801.437542
# 4  58.0    male  32.010000     no  southeast         1  11946.625900

# %%
# Encoding:
df = pd.get_dummies(df, drop_first=True)

# %%
# top records, after encoding:
df.head()
# Out:
#     age        bmi  children       charges  sex_male  smoker_yes  \
# 0  21.0  25.745000         2   3279.868550         1           0
# 1  37.0  25.744165         3  21454.494239         0           1
# 2  18.0  30.030000         1   1720.353700         1           0
# 3  37.0  30.676891         3   6801.437542         1           0
# 4  58.0  32.010000         1  11946.625900         1           0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 0
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 0                 0                 0
# 4                 0                 1                 0

# %%
df.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes',
#        'region_northwest', 'region_southeast', 'region_southwest'],
#       dtype='object')

# %%
df = df[['age','sex_male','smoker_yes','bmi','children','region_northwest','region_southeast','region_southwest','charges']]

df.head()
# Out:
#     age  sex_male  smoker_yes        bmi  children  region_northwest  \
# 0  21.0         1           0  25.745000         2                 0
# 1  37.0         0           1  25.744165         3                 0
# 2  18.0         1           0  30.030000         1                 0
# 3  37.0         1           0  30.676891         3                 0
# 4  58.0         1           0  32.010000         1                 0
#
#    region_southeast  region_southwest       charges
# 0                 0                 0   3279.868550
# 1                 1                 0  21454.494239
# 2                 1                 0   1720.353700
# 3                 0                 0   6801.437542
# 4                 1                 0  11946.625900

# %%
df.corr()
# Out:
#                        age  sex_male  smoker_yes       bmi  children  \
# age               1.000000 -0.152059    0.026157  0.143534 -0.060885
# sex_male         -0.152059  1.000000    0.078318 -0.011215  0.147182
# smoker_yes        0.026157  0.078318    1.000000  0.045921 -0.183507
# bmi               0.143534 -0.011215    0.045921  1.000000 -0.041996
# children         -0.060885  0.147182   -0.183507 -0.041996  1.000000
# region_northwest  0.097152 -0.180701   -0.034372  0.014488 -0.087854
# region_southeast  0.048022  0.001615    0.048327  0.070051  0.068287
# region_southwest -0.128405  0.077158   -0.072273 -0.051727  0.095720
# charges           0.299100  0.092703    0.777175  0.211325 -0.075089
#
#                   region_northwest  region_southeast  region_southwest  \
# age                       0.097152          0.048022         -0.128405
# sex_male                 -0.180701          0.001615          0.077158
# smoker_yes               -0.034372          0.048327         -0.072273
# bmi                       0.014488          0.070051         -0.051727
# children                 -0.087854          0.068287          0.095720
# region_northwest          1.000000         -0.362102         -0.320068
# region_southeast         -0.362102          1.000000         -0.345910
# region_southwest         -0.320068         -0.345910          1.000000
# charges                  -0.043049          0.050719         -0.122019
#
#                    charges
# age               0.299100
# sex_male          0.092703
# smoker_yes        0.777175
# bmi               0.211325
# children         -0.075089
# region_northwest -0.043049
# region_southeast  0.050719
# region_southwest -0.122019
# charges           1.000000

# %%
plt.figure(figsize=(21,18))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df.corr(),linewidths=0.1,vmax=1.0,
            square=True, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
df.to_csv("processed/insurance_2.csv")

# %%
df.drop(["region_northwest","region_southeast",'region_southwest'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     age  sex_male  smoker_yes        bmi  children       charges
# 0  21.0         1           0  25.745000         2   3279.868550
# 1  37.0         0           1  25.744165         3  21454.494239
# 2  18.0         1           0  30.030000         1   1720.353700
# 3  37.0         1           0  30.676891         3   6801.437542
# 4  58.0         1           0  32.010000         1  11946.625900

# %%
plt.figure(figsize=(21,18))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df.corr(),linewidths=0.1,vmax=1.0,
            square=True, linecolor='white', annot=True);

# %%
df.to_csv("processed/Insurance_treated_data.csv")
